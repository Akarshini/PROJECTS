# %%
import cv2

# %%
from deepface import DeepFace

# %%
img =cv2.imread('happpyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.31s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.621674154492439e-08,
#    'disgust': 2.5753200570341472e-11,
#    'fear': 2.208148686122513e-06,
#    'happy': 99.99469518661499,
#    'sad': 4.306603074155646e-07,
#    'surprise': 6.295351084872891e-06,
#    'neutral': 0.0052994510042481124},
#   'dominant_emotion': 'happy',
#   'region': {'x': 145, 'y': 37, 'w': 79, 'h': 79},
#   'age': 25,
#   'gender': {'Woman': 5.781963840126991, 'Man': 94.21803951263428},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.015402493590954691,
#    'indian': 0.07193064666353166,
#    'black': 0.0005035259164287709,
#    'white': 81.5089225769043,
#    'middle eastern': 15.056945383548737,
#    'latino hispanic': 3.3462952822446823},
#   'dominant_race': 'white'}]

# %%
predictions = [{'emotion': {'angry': 4.621674154492439e-08,   'disgust': 2.5753200570341472e-11,   'fear': 2.208148686122513e-06,   'happy': 99.99469518661499,   'sad': 4.306603074155646e-07,   'surprise': 6.295351084872891e-06,   'neutral': 0.0052994510042481124},  'dominant_emotion': 'happy',  'region': {'x': 145, 'y': 37, 'w': 79, 'h': 79},  'age': 25,  'gender': {'Woman': 5.781963840126991, 'Man': 94.21803951263428},  'dominant_gender': 'Man',  'race': {'asian': 0.015402493590954691,   'indian': 0.07193064666353166,   'black': 0.0005035259164287709,   'white': 81.5089225769043,   'middle eastern': 15.056945383548737,   'latino hispanic': 3.3462952822446823},  'dominant_race': 'white'}]

dominant_emotion = predictions[0]['dominant_emotion']
print(dominant_emotion) # Output: 'happy'
# Out:
# happy

# %%
type(predictions)
# Out:
# list

# %% [markdown]
# # we are trying to draw a rectangle across the face

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y),(x+w, y+h),(0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

predictions = [{'emotion': {'angry': 4.621674154492439e-08, 'disgust': 2.5753200570341472e-11, 'fear': 2.208148686122513e-06, 'happy': 99.99469518661499, 'sad': 4.306603074155646e-07, 'surprise': 6.295351084872891e-06, 'neutral': 0.0052994510042481124}, 'dominant_emotion': 'happy', 'region': {'x': 145, 'y': 37, 'w': 79, 'h': 79}, 'age': 25, 'gender': {'Woman': 5.781963840126991, 'Man': 94.21803951263428}, 'dominant_gender': 'Man', 'race': {'asian': 0.015402493590954691, 'indian': 0.07193064666353166, 'black': 0.0005035259164287709, 'white': 81.5089225769043, 'middle eastern': 15.056945383548737, 'latino hispanic': 3.3462952822446823}, 'dominant_race': 'white'}]

dominant_emotion = predictions[0]['dominant_emotion']
print(dominant_emotion) # Output: 'happy'

cv2.putText(img,
            dominant_emotion,
            (0, 50),
            font,
            1,
            (0, 0, 255),
            2,
            cv2.LINE_4)
# Out:
# happy
# array([[[ 32,  89,  88],
#         [ 37,  95,  94],
#         [ 51, 114, 112],
#         ...,
#         [254, 246, 239],
#         [254, 246, 239],
#         [254, 246, 239]],
#
#        [[ 36,  90,  90],
#         [ 41,  98,  97],
#         [ 55, 115, 114],
#         ...,
#         [254, 246, 239],
#         [254, 246, 239],
#         [254, 246, 239]],
#
#        [[ 25,  74,  72],
#         [ 32,  82,  80],
#         [ 47, 102,  99],
#         ...,
#         [254, 246, 239],
#         [254, 246, 239],
#         [254, 246, 239]],
#
#        ...,
#
#        [[ 63, 114,  94],
#         [ 63, 115,  92],
#         [ 62, 113,  93],
#         ...,
#         [102, 147, 158],
#         [ 80, 126, 137],
#         [ 78, 125, 133]],
#
#        [[ 65, 121,  98],
#         [ 64, 121,  96],
#         [ 64, 120,  97],
#         ...,
#         [101, 149, 155],
#         [ 75, 125, 131],
#         [ 74, 126, 132]],
#
#        [[ 70, 131, 105],
#         [ 69, 130, 102],
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad_women.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.26it/s]

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions
# Out:
# [{'emotion': {'angry': 12.649838626384735,
#    'disgust': 0.0005674860403814819,
#    'fear': 1.2786920182406902,
#    'happy': 0.004517777415458113,
#    'sad': 18.296650052070618,
#    'surprise': 2.8539793106574507e-05,
#    'neutral': 67.76970624923706},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 543, 'y': 98, 'w': 280, 'h': 280},
#   'age': 30,
#   'gender': {'Woman': 82.20282793045044, 'Man': 17.797167599201202},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 99.86443518784256,
#    'indian': 0.054902470217792404,
#    'black': 6.588789284981335e-06,
#    'white': 0.026866780681977016,
#    'middle eastern': 3.37034853908259e-05,
#    'latino hispanic': 0.05375770008237363},
#   'dominant_race': 'asian'}]

# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)

# Check if the webcam is opened correctly 
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

i = 0

# Define color codes for each emotion
emotion_colors = {
    'angry': (0, 0, 255),
    'happy': (0, 255, 0),
    'neutral': (128, 128, 128),
    'sad': (255, 0, 0),
    'surprise': (0, 255, 255),
    'fear': (255, 255, 0),
    'disgust': (255, 0, 255)
}

while True:
    ret, frame = cap.read()
    result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4)

    # Draw a rectangle around the faces and display the dominant emotion
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        # Display the dominant emotion
        dominant_emotion = result[0]['dominant_emotion']
        cv2.putText(frame, dominant_emotion, (x, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Display the emotions with scores
        emotions = result[0]['emotion']
        for emotion, score in emotions.items():
            emotion_text = f"{emotion.capitalize()}: {score:.2f}%" 
            color = emotion_colors.get(emotion, (255, 255, 255)) # Default to white if emotion is not in the color dictionary
            cv2.putText(frame, emotion_text, (50, 50 + 30 * i), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_4)
            i += 1

    cv2.imshow('Demo video', frame)
    if cv2.waitKey(2) & 0xFF== ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Action: emotion: 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.13it/s]
# ...
# ...
# Action: emotion: 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.58it/s]
